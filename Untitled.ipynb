# %%
import pandas as pd
import csv

df = pd.read_csv('learning_path_bus.csv')
df['name'].tolist()
# Out:
# ['Become a Technical Recruiter',
#  'Getting Started with Microsoft Outlook',
#  'Become a Software Project Manager',
#  'Improve Your Presentation Skills',
#  'Become a Craft Business Owner',
#  'Master Microsoft OneNote',
#  'Become a Small Business Owner',
#  'Become a Digital Advertising Specialist',
#  'Managing Performance',
#  'Become a Manager',
#  'Become an SEO Expert',
#  'Become a Project Coordinator',
#  'Become a Customer Service Manager',
#  'Become a Content Strategist',
#  'Become a Project Manager',
#  'Become a Business Unit Manager',
#  'Become a Corporate Financial Planning Analyst',
#  'Become a Social Media Marketer',
#  'Become a Social Media Advertising Specialist',
#  'Become an L&D Professional',
#  'Getting Started with Microsoft PowerPoint',
#  'Become a Leader',
#  'Become a Customer Service Specialist',
#  'Become a Sales Representative',
#  'Become a Government Project Manager',
#  'Become a Public Relations Specialist',
#  'Get Ahead as a Military Spouse',
#  'Improve Your Interoffice Politics Skills',
#  'Become a Portfolio Manager',
#  'Become an AMA Professional Certified Marketer in Digital Marketing',
#  'Become an Administrative Professional',
#  'Fostering Collaboration',
#  'Transition From Military to Student Life',
#  'Become a Project Scheduler',
#  'Get Ahead in The Job Market After a Layoff',
#  'Become a Corporate Recruiter',
#  'Master Microsoft Outlook',
#  'Women in Leadership',
#  'Fostering Innovation',
#  'Become a Program Manager',
#  'Become a Marketing Specialist',
#  'Become a Digital Marketer',
#  'Prepare for the PMI ACP Certification',
#  'Become an Inclusive Leader',
#  'Become an Excel 2013 Microsoft Office Specialist',
#  'Getting Started with Microsoft Word',
#  'Become an External Recruiter',
#  'Become a Business Operations Associate',
#  'Getting Started with Microsoft Excel',
#  'Prepare for the Word 2013 Microsoft Office Specialist (MOS) Expert Exam',
#  'Improve Your Microsoft Word Skills',
#  'Become a Healthcare Project Manager',
#  'Become a Marketing Manager',
#  'Become a Sales Manager',
#  'Advance Your Skills as an Individual Contributor',
#  'Become a Content Marketer',
#  'Become a High Performer',
#  'Improve Your Problem-Solving Skills',
#  'Prepare for the Excel 2013 Microsoft Office Specialist (MOS) Expert Exam',
#  'Become an Agile Project Manager',
#  'Become an Online Marketing Manager',
#  'Become an Outlook 2013 Microsoft Office Specialist',
#  'Become an Instructional Developer',
#  'Become an Instructional Designer',
#  'Becoming a Six Sigma Green Belt',
#  'Managing Change',
#  'Become a Business Analyst',
#  'Working Smarter with Microsoft 365',
#  'Master Microsoft PowerPoint',
#  'Transition from Military to Civilian Employment',
#  'Finding and Retaining Talent',
#  'Become an Online Instructor',
#  'Advance Your Skills as a Manager',
#  'Master In-Demand Professional Soft Skills',
#  'Become a Successful Job Hunter',
#  'Getting Started with Microsoft OneNote',
#  'Become a PowerPoint 2013 Microsoft Office Specialist',
#  'Improve Your Teamwork Skills',
#  'Become a Senior Manager',
#  'Improve Your Coaching Skills as a Manager',
#  'Become a Thought Leader',
#  'Become a Bookkeeper',
#  'Master Microsoft Word',
#  'Get Ahead in the On-Demand Gig Economy',
#  'Become an Accounts Payable Officer',
#  'Master Microsoft Excel',
#  'Become an HR Business Partner',
#  'Become a Word 2013 Microsoft Office Specialist',
#  'Become a Successful Remote Worker',
#  'Become a Technical Program Manager',
#  'Improve Your Microsoft Excel Skills',
#  'Becoming a Six Sigma Black Belt',
#  'Getting Started with Microsoft 365',
#  'Stay Ahead in Personal Finance',
#  'Become an Access 2013 Microsoft Office Specialist',
#  'Digital Transformation for Leaders',
#  'Become a SharePoint 2013 Microsoft Office Specialist',
#  'Improve Your Organizational Skills']

# %%
df.groupby('skills').count().index.tolist()
# Out:
# ['Accounting',
#  'Advertising',
#  'Agile Project Management',
#  'Brand Management',
#  'Business Operations',
#  'Business Strategy',
#  'Calendaring',
#  'Camtasia',
#  'Career Development',
#  'Coaching',
#  'Communication',
#  'Compensation & Benefits',
#  'Content Marketing',
#  'Contractors',
#  'Corporate Finance',
#  'Critical Thinking',
#  'Cross-team Collaboration',
#  'Customer Support',
#  'Data Analysis',
#  'Data Visualization',
#  'Digital Transformation',
#  'Diversity & Inclusion',
#  'E-Learning',
#  'Entrepreneurship',
#  'Financial Analysis',
#  'Government Project Management',
#  'Healthcare Management',
#  'Human Resources (HR)',
#  'Job Search Strategies',
#  'Leadership',
#  'Leadership Development',
#  'Leading Meetings',
#  'Life Skills',
#  'Management',
#  'Microsoft Excel',
#  'Microsoft Outlook',
#  'Microsoft PowerPoint',
#  'Microsoft Project',
#  'Microsoft Word',
#  'Note Taking',
#  'Office 365',
#  'Office Administration',
#  'Online Marketing',
#  'Organizational Leadership',
#  'Personal Finance',
#  'Program Management',
#  'Project Management',
#  'Sales',
#  'Scheduling',
#  'Scrum',
#  'Search Engine Optimization (SEO)',
#  'SharePoint Designer',
#  'Six Sigma',
#  'Social Media Advertising',
#  'Staff Development',
#  'Strategic Public Relations Planning',
#  'Talent Management',
#  'Teamwork',
#  'Test Preparation',
#  'Time Management',
#  'Web Content Writing',
#  'Word Processing']

# %%
df = pd.read_csv('learning_path_bus.csv')

def linkedin_learning_path_business():
    '''This is a method that returns a CSV file of all the learning paths in the business category.'''
    return(df)

linkedin_learning_path_business()
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0    1562460814-1906  https://www.linkedin.com/learning/topics/busin...
# 1    1562460814-1929  https://www.linkedin.com/learning/topics/busin...
# 2    1562460814-1933  https://www.linkedin.com/learning/topics/busin...
# 3    1562460814-1869  https://www.linkedin.com/learning/topics/busin...
# 4    1562460814-1912  https://www.linkedin.com/learning/topics/busin...
# 5    1562460814-1901  https://www.linkedin.com/learning/topics/busin...
# 6    1562460814-1945  https://www.linkedin.com/learning/topics/busin...
# 7    1562460814-1935  https://www.linkedin.com/learning/topics/busin...
# 8    1562460814-1904  https://www.linkedin.com/learning/topics/busin...
# 9    1562460814-1921  https://www.linkedin.com/learning/topics/busin...
# 10   1562460814-1924  https://www.linkedin.com/learning/topics/busin...
# 11   1562460814-1879  https://www.linkedin.com/learning/topics/busin...
# 12   1562460814-1934  https://www.linkedin.com/learning/topics/busin...
# 13   1562460814-1944  https://www.linkedin.com/learning/topics/busin...
# 14   1562460814-1865  https://www.linkedin.com/learning/topics/busin...
# 15   1562460814-1910  https://www.linkedin.com/learning/topics/busin...
# 16   1562460814-1873  https://www.linkedin.com/learning/topics/busin...
# 17   1562460814-1871  https://www.linkedin.com/learning/topics/busin...
# 18   1562460814-1892  https://www.linkedin.com/learning/topics/busin...
#
# [98 rows x 4 columns]

# %%
df_blp = pd.read_csv('learning_path_bus.csv')
def linkedin_learning_path_business_authors():
    '''This is a method that returns a dictionary of skills and their learning paths in the business category.'''
    print(df_blp.groupby('skills')['name'].apply(list).to_dict())
# Out:
# {'Accounting': ['Become an Accounts Payable Officer'],
#  'Advertising': ['Become a Social Media Advertising Specialist'],
#  'Agile Project Management': ['Prepare for the PMI ACP Certification',
#   'Become an Agile Project Manager'],
#  'Brand Management': ['Become a Marketing Manager'],
#  'Business Operations': ['Become a Business Operations Associate'],
#  'Business Strategy': ['Become a Business Analyst'],
#  'Calendaring': ['Become an Outlook 2013 Microsoft Office Specialist'],
#  'Camtasia': ['Become an Instructional Designer'],
#  'Career Development': ['Get Ahead in The Job Market After a Layoff'],
#  'Coaching': ['Improve Your Coaching Skills as a Manager'],
#  'Communication': ['Get Ahead as a Military Spouse',
#   'Improve Your Interoffice Politics Skills',
#   'Become a Program Manager',
#   'Become a High Performer',
#   'Transition from Military to Civilian Employment',
#   'Become a Thought Leader'],
#  'Compensation & Benefits': ['Finding and Retaining Talent'],
#  'Content Marketing': ['Become a Content Strategist',
#   'Become a Marketing Specialist',
#   'Become an Online Marketing Manager'],
#  'Contractors': ['Get Ahead in the On-Demand Gig Economy'],
#  'Corporate Finance': ['Become a Bookkeeper'],
#  'Critical Thinking': ['Improve Your Problem-Solving Skills'],
#  'Cross-team Collaboration': ['Improve Your Teamwork Skills'],
#  'Customer Support': ['Become a Customer Service Manager',
#   'Become a Customer Service Specialist'],
#  'Data Analysis': ['Become an Access 2013 Microsoft Office Specialist'],
#  'Data Visualization': ['Become an Excel 2013 Microsoft Office Specialist',
#   'Improve Your Microsoft Excel Skills'],
#  'Digital Transformation': ['Digital Transformation for Leaders'],
#  'Diversity & Inclusion': ['Become an Inclusive Leader'],
#  'E-Learning': ['Become an Instructional Developer',
#   'Become an Online Instructor'],
#  'Entrepreneurship': ['Become a Craft Business Owner'],
#  'Financial Analysis': ['Become a Corporate Financial Planning Analyst'],
#  'Government Project Management': ['Become a Government Project Manager'],
#  'Healthcare Management': ['Become a Healthcare Project Manager'],
#  'Human Resources (HR)': ['Become a Technical Recruiter',
#   'Become a Corporate Recruiter',
#   'Become an External Recruiter',
#   'Become an HR Business Partner'],
#  'Job Search Strategies': ['Become a Successful Job Hunter'],
#  'Leadership': ['Women in Leadership'],
#  'Leadership Development': ['Advance Your Skills as an Individual Contributor'],
#  'Leading Meetings': ['Become a Project Coordinator'],
#  'Life Skills': ['Master In-Demand Professional Soft Skills'],
#  'Management': ['Become a Small Business Owner', 'Fostering Innovation'],
#  'Microsoft Excel': ['Getting Started with Microsoft Excel',
#   'Prepare for the Excel 2013 Microsoft Office Specialist (MOS) Expert Exam',
#   'Working Smarter with Microsoft 365',
#   'Master Microsoft Excel',
#   'Getting Started with Microsoft 365'],
#  'Microsoft Outlook': ['Master Microsoft Outlook'],
#  'Microsoft PowerPoint': ['Improve Your Presentation Skills',
#   'Getting Started with Microsoft PowerPoint',
#   'Master Microsoft PowerPoint',
#   'Become a PowerPoint 2013 Microsoft Office Specialist'],
#  'Microsoft Project': ['Become a Project Manager'],
#  'Microsoft Word': ['Getting Started with Microsoft Word'],
#  'Note Taking': ['Master Microsoft OneNote',
#   'Getting Started with Microsoft OneNote'],
#  'Office 365': ['Getting Started with Microsoft Outlook'],
#  'Office Administration': ['Become an Administrative Professional'],
#  'Online Marketing': ['Become an AMA Professional Certified Marketer in Digital Marketing'],
#  'Organizational Leadership': ['Become a Business Unit Manager',
#   'Become a Leader',
#   'Managing Change'],
#  'Personal Finance': ['Stay Ahead in Personal Finance'],
#  'Program Management': ['Become a Technical Program Manager'],
#  'Project Management': ['Become a Portfolio Manager'],
#  'Sales': ['Become a Sales Representative', 'Become a Sales Manager'],
#  'Scheduling': ['Become a Project Scheduler'],
#  'Scrum': ['Become a Software Project Manager'],
#  'Search Engine Optimization (SEO)': ['Become a Digital Advertising Specialist',
#   'Become an SEO Expert',
#   'Become a Digital Marketer'],
#  'SharePoint Designer': ['Become a SharePoint 2013 Microsoft Office Specialist'],
#  'Six Sigma': ['Becoming a Six Sigma Green Belt',
#   'Becoming a Six Sigma Black Belt'],
#  'Social Media Advertising': ['Become a Social Media Marketer'],
#  'Staff Development': ['Become an L&D Professional'],
#  'Strategic Public Relations Planning': ['Become a Public Relations Specialist'],
#  'Talent Management': ['Managing Performance',
#   'Become a Manager',
#   'Advance Your Skills as a Manager',
#   'Become a Senior Manager'],
#  'Teamwork': ['Fostering Collaboration'],
#  'Test Preparation': ['Transition From Military to Student Life'],
#  'Time Management': ['Become a Successful Remote Worker',
#   'Improve Your Organizational Skills'],
#  'Web Content Writing': ['Become a Content Marketer'],
#  'Word Processing': ['Prepare for the Word 2013 Microsoft Office Specialist (MOS) Expert Exam',
#   'Improve Your Microsoft Word Skills',
#   'Master Microsoft Word',
#   'Become a Word 2013 Microsoft Office Specialist']}

# %%
linkedin_learning_path_business_authors()
# Out:
# {'Six Sigma': 'Becoming a Six Sigma Black Belt', 'Staff Development': 'Become an L&D Professional', 'Compensation & Benefits': 'Finding and Retaining Talent', 'Content Marketing': 'Become an Online Marketing Manager', 'Microsoft PowerPoint': 'Become a PowerPoint 2013 Microsoft Office Specialist', 'Talent Management': 'Become a Senior Manager', 'Critical Thinking': 'Improve Your Problem-Solving Skills', 'Leadership': 'Women in Leadership', 'Project Management': 'Become a Portfolio Manager', 'Agile Project Management': 'Become an Agile Project Manager', 'Entrepreneurship': 'Become a Craft Business Owner', 'Test Preparation': 'Transition From Military to Student Life', 'Word Processing': 'Become a Word 2013 Microsoft Office Specialist', 'Organizational Leadership': 'Managing Change', 'Advertising': 'Become a Social Media Advertising Specialist', 'Diversity & Inclusion': 'Become an Inclusive Leader', 'Business Operations': 'Become a Business Operations Associate', 'Financial Analysis': 'Become a Corporate Financial Planning Analyst', 'Brand Management': 'Become a Marketing Manager', 'Job Search Strategies': 'Become a Successful Job Hunter', 'Data Visualization': 'Improve Your Microsoft Excel Skills', 'Scheduling': 'Become a Project Scheduler', 'Management': 'Fostering Innovation', 'Microsoft Excel': 'Getting Started with Microsoft 365', 'Program Management': 'Become a Technical Program Manager', 'E-Learning': 'Become an Online Instructor', 'Leadership Development': 'Advance Your Skills as an Individual Contributor', 'Office 365': 'Getting Started with Microsoft Outlook', 'Office Administration': 'Become an Administrative Professional', 'Microsoft Word': 'Getting Started with Microsoft Word', 'Customer Support': 'Become a Customer Service Specialist', 'Accounting': 'Become an Accounts Payable Officer', 'Camtasia': 'Become an Instructional Designer', 'Healthcare Management': 'Become a Healthcare Project Manager', 'Human Resources (HR)': 'Become an HR Business Partner', 'Strategic Public Relations Planning': 'Become a Public Relations Specialist', 'Digital Transformation': 'Digital Transformation for Leaders', 'Teamwork': 'Fostering Collaboration', 'Sales': 'Become a Sales Manager', 'Personal Finance': 'Stay Ahead in Personal Finance', 'Corporate Finance': 'Become a Bookkeeper', 'Leading Meetings': 'Become a Project Coordinator', 'Government Project Management': 'Become a Government Project Manager', 'Online Marketing': 'Become an AMA Professional Certified Marketer in Digital Marketing', 'Calendaring': 'Become an Outlook 2013 Microsoft Office Specialist', 'Scrum': 'Become a Software Project Manager', 'Cross-team Collaboration': 'Improve Your Teamwork Skills', 'Microsoft Project': 'Become a Project Manager', 'Contractors': 'Get Ahead in the On-Demand Gig Economy', 'Life Skills': 'Master In-Demand Professional Soft Skills', 'Note Taking': 'Getting Started with Microsoft OneNote', 'Search Engine Optimization (SEO)': 'Become a Digital Marketer', 'Data Analysis': 'Become an Access 2013 Microsoft Office Specialist', 'Microsoft Outlook': 'Master Microsoft Outlook', 'Coaching': 'Improve Your Coaching Skills as a Manager', 'Social Media Advertising': 'Become a Social Media Marketer', 'SharePoint Designer': 'Become a SharePoint 2013 Microsoft Office Specialist', 'Communication': 'Become a Thought Leader', 'Time Management': 'Improve Your Organizational Skills', 'Career Development': 'Get Ahead in The Job Market After a Layoff', 'Web Content Writing': 'Become a Content Marketer', 'Business Strategy': 'Become a Business Analyst'}

# %%
class Linkedin_lp_creative:

    def __init__(self):
        self.df_clp = pd.read_csv('learning_path_cre.csv')

    def csv(self):
        '''This is a method that returns a CSV file of all the learning paths in the business category.'''
        return(self.df_clp)

    def courseList(self):
        '''This is a method that returns a list of all the learning paths in the business category.'''
        return(self.df_clp['name'].tolist())

    def skillsList(self):
        '''This is a method that returns a list of all the skills in the business category.'''
        return(self.df_clp.groupby('skills').count().index.tolist())

    def skillsdict(self):
        '''This is a method that returns a dictionary of skills and their learning paths in the business category.'''
        return(self.df_clp.groupby('skills')['name'].apply(list).to_dict())
    
a=Linkedin_lp_creative
a.csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-b6f2ff30f93a> in <module>()
#      21
#      22 a=Linkedin_lp_creative
# ---> 23 a.csv()
#
# TypeError: csv() missing 1 required positional argument: 'self'

# %%
class Linkedin_lp_business:

    def __init__(self):
        self.df_blp = pd.read_csv('learning_path_bus.csv')

    def csv(self):
        '''This is a method that returns a CSV file of all the learning paths in the business category.'''
        return(self.df_blp)

    def courseList(self):
        '''This is a method that returns a list of all the learning paths in the business category.'''
        return(self.df_blp['name'].tolist())

    def skillsList(self):
        '''This is a method that returns a list of all the skills in the business category.'''
        return(self.df_blp.groupby('skills').count().index.tolist())

    def skillsdict(self):
        '''This is a method that returns a dictionary of skills and their learning paths in the business category.'''
        return(self.df_blp.groupby('skills')['name'].apply(list).to_dict())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-42-72df7a248a78> in <module>()
# ----> 1 import Linkedin_lp_business
#       2
#       3 if __name__ == '__main__':
#       4
#       5     a=Linkedin_lp_business()
#
# ImportError: No module named 'Linkedin_lp_business'
